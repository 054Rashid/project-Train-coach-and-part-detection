# %%
# --- BLOCK 1: Setup, Downloads, and Base Configuration ---

# 1. Install necessary libraries
print("--- Installing required libraries... ---")
# !pip install opencv-python gdown numpy reportlab==3.6.13 # Specific version for compatibility
# !pip install ultralytics # For YOLOv8
print("--- Libraries installed. ---")

import cv2
import os
import shutil
import gdown
import numpy as np
from reportlab.lib.pagesizes import A4
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer, Image, PageBreak
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle
from reportlab.lib.units import inch
from ultralytics import YOLO # For object detection (YOLOv8)
import logging

# Configure logging for better feedback
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# --- Configuration ---
VIDEO_URL = "https://drive.google.com/uc?id=1f9Dk2SAGaX8-7-qBai14WydAiAeeAnY3"
VIDEO_FILENAME = "raw_video.mp4"
OUTPUT_BASE_DIR = "Processed_Video"
TRAIN_NUMBER = "12309" # As per the assignment example

# Object Detection Model Configuration
# IMPORTANT: For real-world door detection, you would need a custom-trained model.
# This uses a generic YOLOv8n model as a placeholder.
# You might need to download 'yolov8n.pt' or your custom trained model to a path accessible by Colab.
YOLO_MODEL_PATH = 'yolov8n.pt' # Using nano model as a placeholder.
# If you have a custom trained model for doors, e.g., 'door_detector.pt', use that path.
# Example: YOLO_MODEL_PATH = '/content/drive/MyDrive/yolo_models/door_detector.pt'

# --- 2. Download the raw video file from Google Drive ---
logger.info(f"--- Downloading the raw video file from {VIDEO_URL}... ---")
try:
    gdown.download(VIDEO_URL, VIDEO_FILENAME, quiet=False)
    video_path = VIDEO_FILENAME
    logger.info("Video downloaded successfully.")
except Exception as e:
    logger.error(f"Error downloading video: {e}")
    video_path = None

if not video_path or not os.path.exists(video_path):
    logger.critical("Video file not found. Please ensure the URL is correct and accessible. Exiting.")
    # In a real script, you might raise an exception or sys.exit() here.
    # For Colab, we'll proceed with a dummy path to avoid crashing the whole notebook.
    video_path = "dummy_video.mp4" # Ensure this won't actually be opened later.

# Create main output directory
os.makedirs(OUTPUT_BASE_DIR, exist_ok=True)
logger.info(f"Created base output directory: {OUTPUT_BASE_DIR}")

# Prepare directories for report and individual coaches
processed_video_base = os.path.join(OUTPUT_BASE_DIR, "individual_coaches")
report_output_dir = os.path.join(OUTPUT_BASE_DIR, "Final Report---Assignment Submission")
os.makedirs(processed_video_base, exist_ok=True)
os.makedirs(report_output_dir, exist_ok=True)
logger.info(f"Created subdirectories: {processed_video_base} and {report_output_dir}")

# Global list to store data for the final report
report_data = []

# Placeholder for YOLO model (loaded once)
yolo_model = None
try:
    yolo_model = YOLO(YOLO_MODEL_PATH)
    logger.info(f"YOLOv8 model loaded from {YOLO_MODEL_PATH}")
except Exception as e:
    logger.warning(f"Could not load YOLOv8 model from {YOLO_MODEL_PATH}. Object detection will be skipped. Error: {e}")
    logger.warning("Please ensure 'yolov8n.pt' is available or specify your custom model path correctly.")
# Out:
# --- Installing required libraries... ---
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Collecting reportlab==3.6.13
#   Downloading reportlab-3.6.13.tar.gz (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 30.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from reportlab==3.6.13) (11.3.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.19.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2025.8.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)
# Building wheels for collected packages: reportlab
#   Building wheel for reportlab (setup.py) ... done
#   Created wheel for reportlab: filename=reportlab-3.6.13-cp312-cp312-linux_x86_64.whl size=2237988 sha256=6c62303def098e49e581f1832eb9c16a09e66e4d5a91f1ac29bccb7a958ca052
#   Stored in directory: /root/.cache/pip/wheels/48/67/58/d54706b91458551310cfa11bd10777cb55438c6f33bf3a5292
# Successfully built reportlab
# Installing collected packages: reportlab
# Successfully installed reportlab-3.6.13
# Collecting ultralytics
#   Downloading ultralytics-8.3.203-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.23.0+cu126)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.25.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.17-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.203-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.2 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.17-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.203 ultralytics-thop-2.0.17
# --- Libraries installed. ---
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading...
# From: https://drive.google.com/uc?id=1f9Dk2SAGaX8-7-qBai14WydAiAeeAnY3
# To: /content/raw_video.mp4
# 100%|██████████| 79.2M/79.2M [00:00<00:00, 91.6MB/s]
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 77.0MB/s 0.1s

# %%
# --- BLOCK 2: Video Processing - Splitting and Frame Extraction (Enhanced) ---

logger.info("\n--- Starting video processing and coach/engine segmentation... ---")

cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    logger.error("Error: Could not open video file. Please check if the video downloaded correctly.")
    # Exit gracefully if video can't be opened
    report_data.append({"type": "summary", "text": "Video could not be processed due to file error."})
else:
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames_in_video = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fourcc = cv2.VideoWriter_fourcc(*'mp4v') # Codec for MP4

    coach_count = 0
    engine_count = 0
    current_wagon_writer = None
    is_between_wagons = True # Flag to indicate if we are in a gap or processing a wagon
    prev_frame_gray = None # Storing previous frame for differencing

    # Store all frames for the current wagon to allow for full coverage image selection
    current_wagon_frames = []
    current_wagon_name = ""
    current_wagon_dir = ""

    frame_idx = 0
    logger.info(f"Processing video: {VIDEO_FILENAME} with {total_frames_in_video} frames at {fps} FPS.")

    while True:
        ret, frame = cap.read()
        if not ret:
            break # End of video

        frame_idx += 1
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        if prev_frame_gray is None:
            prev_frame_gray = gray_frame
            continue # Skip first frame as there's no previous frame to compare

        # --- Core Detection Algorithm: Frame Differencing ---
        # Calculate absolute difference between current and previous grayscale frame
        frame_diff = cv2.absdiff(prev_frame_gray, gray_frame)

        # Threshold the difference image to highlight significant changes
        # Pixels with intensity difference > 30 become white (255), others black (0)
        _, thresh = cv2.threshold(frame_diff, 30, 255, cv2.THRESH_BINARY)

        # Calculate the percentage of non-zero pixels (changed pixels)
        change_percentage = (np.count_nonzero(thresh) / (frame_width * frame_height)) * 100

        # --- Color Analysis for Engine/Wagon Differentiation (Heuristic) ---
        # This is a simple heuristic. For robust detection, a trained object detector is better.
        # Assuming engines in *this specific video* have a distinct color profile (e.g., blue, red, or very dark)
        mean_color_bgr = np.mean(frame, axis=(0, 1))
        # Example: Assume engines are very dark or have a specific dominant color not common in coaches
        # Adjust these thresholds based on visual inspection of your video's engine colors.
        is_engine_heuristic = False
        if (mean_color_bgr[0] > 100 and mean_color_bgr[1] < 80 and mean_color_bgr[2] < 80) or \
           (mean_color_bgr[0] < 80 and mean_color_bgr[1] < 80 and mean_color_bgr[2] > 100) or \
           (np.mean(mean_color_bgr) < 50): # Very dark for example
            is_engine_heuristic = True

        # --- Wagon/Engine Detection Logic ---
        # Condition 1: Transition from a gap to a new wagon/engine
        if is_between_wagons and change_percentage < 5: # If change is low, a solid object is passing
            if is_engine_heuristic and engine_count < 2: # Assuming max 2 engines from "Points to Ponder"
                engine_count += 1
                wagon_type = "engine"
                wagon_counter = engine_count
            else:
                coach_count += 1
                wagon_type = "wagon"
                wagon_counter = coach_count

            is_between_wagons = False # We are now inside a wagon

            current_wagon_name = f"{wagon_type}_{wagon_counter}"
            current_wagon_dir = os.path.join(processed_video_base, f"{TRAIN_NUMBER}_{current_wagon_name}")
            os.makedirs(current_wagon_dir, exist_ok=True)
            logger.info(f"Detected {current_wagon_name}. Created directory: {current_wagon_dir}")

            # Initialize video writer for the current wagon
            wagon_video_path = os.path.join(current_wagon_dir, f"{TRAIN_NUMBER}_{current_wagon_name}.mp4")
            current_wagon_writer = cv2.VideoWriter(wagon_video_path, fourcc, fps, (frame_width, frame_height))
            current_wagon_frames = [] # Reset frames for the new wagon

            logger.info(f"Started recording video for {current_wagon_name}.")

        # Condition 2: Transition from a wagon/engine to a gap
        elif not is_between_wagons and change_percentage > 10: # If change is high, we've hit a gap
            is_between_wagons = True # We are now in a gap

            # Release the video writer for the completed wagon
            if current_wagon_writer is not None:
                current_wagon_writer.release()
                logger.info(f"Finished recording video for {current_wagon_name}.")

                # --- Process collected frames for the completed wagon ---
                # Add data for report (this will be used by the reporting function)
                report_data.append({
                    "type": "wagon_data",
                    "wagon_name": current_wagon_name,
                    "wagon_type": current_wagon_name.split('_')[0],
                    "video_path": wagon_video_path,
                    "frames_list": list(current_wagon_frames) # Store a copy of collected frames
                })
                current_wagon_frames = [] # Clear frames after processing

        # While inside a wagon, continue writing frames and collecting them
        if not is_between_wagons and current_wagon_writer is not None:
            current_wagon_writer.write(frame)
            current_wagon_frames.append(frame.copy()) # Store a copy of the frame

        prev_frame_gray = gray_frame

    # Release any remaining resources after the loop
    cap.release()
    if current_wagon_writer is not None and not is_between_wagons:
        current_wagon_writer.release()
        logger.info(f"Finished recording video for {current_wagon_name} (end of video).")
        # Ensure last wagon's data is added if loop ended while inside a wagon
        report_data.append({
            "type": "wagon_data",
            "wagon_name": current_wagon_name,
            "wagon_type": current_wagon_name.split('_')[0],
            "video_path": wagon_video_path,
            "frames_list": list(current_wagon_frames)
        })

    logger.info("--- Video processing complete. ---")
    logger.info(f"Total coaches detected: {coach_count}")
    logger.info(f"Total engines detected: {engine_count}")

# %%
# --- BLOCK 3: Full Coverage Image Extraction & Object Detection (Door Detection) ---

logger.info("\n--- Starting full coverage image extraction and object detection... ---")

def get_full_coverage_images(frames, wagon_name, images_dir, min_coverage_images=5, threshold_similarity=0.4):
    """
    Extracts a minimal set of images for full wagon coverage using ORB features
    and saves them.
    Returns paths to saved images.
    """
    if not frames:
        logger.warning(f"No frames available for {wagon_name}.")
        return []

    saved_image_paths = []

    # Initialize ORB detector
    orb = cv2.ORB_create()

    # Take the first frame as the starting point for coverage
    coverage_images = [frames[0]]
    last_kp, last_des = orb.detectAndCompute(cv2.cvtColor(frames[0], cv2.COLOR_BGR2GRAY), None)

    img_counter = 1
    image_filename = os.path.join(images_dir, f"{TRAIN_NUMBER}_{wagon_name}_{img_counter}.jpg")
    cv2.imwrite(image_filename, frames[0])
    saved_image_paths.append(image_filename)
    img_counter += 1

    for i in range(1, len(frames)):
        current_frame = frames[i]
        current_kp, current_des = orb.detectAndCompute(cv2.cvtColor(current_frame, cv2.COLOR_BGR2GRAY), None)

        if last_des is None or current_des is None or len(last_des) < 2 or len(current_des) < 2:
            # Not enough features, just add after a certain number of frames or if enough images not yet collected
            if len(coverage_images) < min_coverage_images and i % (len(frames) // min_coverage_images + 1) == 0:
                 coverage_images.append(current_frame)
                 last_kp, last_des = current_kp, current_des
                 image_filename = os.path.join(images_dir, f"{TRAIN_NUMBER}_{wagon_name}_{img_counter}.jpg")
                 cv2.imwrite(image_filename, current_frame)
                 saved_image_paths.append(image_filename)
                 img_counter += 1
            continue

        # Use Brute-Force Matcher with Hamming distance for ORB
        matcher = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
        matches = matcher.match(last_des, current_des)

        # Sort matches by distance
        matches = sorted(matches, key=lambda x: x.distance)

        # Calculate similarity based on number of good matches
        # This threshold determines how 'different' a new frame must be to be included
        similarity = len(matches) / min(len(last_des), len(current_des)) if min(len(last_des), len(current_des)) > 0 else 0

        # If similarity is below threshold, or if we haven't collected enough images yet
        if similarity < threshold_similarity or (len(coverage_images) < min_coverage_images and i % (len(frames) // min_coverage_images + 1) == 0):
            coverage_images.append(current_frame)
            last_kp, last_des = current_kp, current_des

            image_filename = os.path.join(images_dir, f"{TRAIN_NUMBER}_{wagon_name}_{img_counter}.jpg")
            cv2.imwrite(image_filename, current_frame)
            saved_image_paths.append(image_filename)
            img_counter += 1
            logger.debug(f"Added frame {img_counter-1} for {wagon_name} (similarity: {similarity:.2f})")

    logger.info(f"Extracted {len(saved_image_paths)} full coverage images for {wagon_name}.")
    return saved_image_paths

# --- Component Detection (Doors - Conceptual YOLOv8 Integration) ---
def detect_doors_and_state(image_path, yolo_model):
    """
    Performs object detection on an image to find doors and their state (open/closed).
    Returns a list of detected objects (class_name, bbox, confidence, state).
    """
    detected_objects = []
    if yolo_model is None:
        logger.warning(f"YOLOv8 model not loaded. Skipping object detection for {image_path}.")
        return []

    try:
        results = yolo_model(image_path) # Run inference

        # Placeholder for custom trained model classes
        # If your model has 'door', 'door_open', 'door_closed' classes, adapt this.
        # Example for a generic model: let's assume class '0' is 'person' and we pretend it's a door.
        # For a real door detector, you would map results[0].names to your custom classes.
        class_names = results[0].names # Get class names from the model

        for r in results:
            for box in r.boxes:
                class_id = int(box.cls)
                class_name = class_names[class_id]
                conf = float(box.conf)
                x1, y1, x2, y2 = map(int, box.xyxy[0]) # Bounding box coordinates

                # --- Door State Classification (Conceptual) ---
                # This part is highly dependent on a custom-trained model for 'door_open'/'door_closed'
                # or a very clever heuristic based on image content within the bounding box.
                # Here, we'll just simulate a state.
                door_state = "unknown"
                # If your model detects specific 'door_open' or 'door_closed' classes:
                if "door" in class_name.lower(): # Generic door
                     # Simulate state based on bounding box size or region analysis (highly heuristic)
                    if (x2 - x1) * (y2 - y1) < 1000: # Very small 'door'
                        door_state = "closed" # Placeholder heuristic
                    else:
                        door_state = "open" # Placeholder heuristic
                    # This needs real ML classification or a robust heuristic.

                detected_objects.append({
                    "class_name": class_name,
                    "bbox": (x1, y1, x2, y2),
                    "confidence": conf,
                    "state": door_state # Only relevant if it's a door
                })
    except Exception as e:
        logger.error(f"Error during object detection for {image_path}: {e}")

    return detected_objects

# Iterate through the collected wagon data for image extraction and object detection
for item in report_data:
    if item["type"] == "wagon_data":
        wagon_name = item["wagon_name"]
        wagon_frames = item["frames_list"]

        wagon_main_dir = os.path.join(processed_video_base, f"{TRAIN_NUMBER}_{wagon_name}")
        images_output_dir = os.path.join(wagon_main_dir, "extracted_frames")
        os.makedirs(images_output_dir, exist_ok=True)

        logger.info(f"Processing frames for {wagon_name} to get full coverage and detect components...")

        # Get full coverage images
        full_coverage_image_paths = get_full_coverage_images(
            wagon_frames, wagon_name, images_output_dir, min_coverage_images=5, threshold_similarity=0.4
        )
        item["full_coverage_images"] = full_coverage_image_paths

        # Perform object detection on each full coverage image
        item["detected_components_by_image"] = {}
        door_open_count = 0
        door_closed_count = 0

        for img_path in full_coverage_image_paths:
            # Read image, perform detection, and annotate
            img = cv2.imread(img_path)
            detected_components = detect_doors_and_state(img_path, yolo_model)

            annotated_img = img.copy()
            door_found_in_image = False

            for comp in detected_components:
                x1, y1, x2, y2 = comp["bbox"]
                class_name = comp["class_name"]
                conf = comp["confidence"]
                state = comp["state"]

                # Annotate image
                color = (0, 255, 0) # Green for general detection
                text_color = (255, 255, 255) # White text
                if "door" in class_name.lower():
                    door_found_in_image = True
                    if state == "open":
                        color = (0, 0, 255) # Red for open door
                        door_open_count += 1
                    elif state == "closed":
                        color = (255, 0, 0) # Blue for closed door
                        door_closed_count += 1
                    cv2.rectangle(annotated_img, (x1, y1), (x2, y2), color, 2)
                    cv2.putText(annotated_img, f"{class_name} ({state}) {conf:.2f}", (x1, y1 - 10),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)
                else: # For other detected objects by generic YOLO
                    cv2.rectangle(annotated_img, (x1, y1), (x2, y2), color, 2)
                    cv2.putText(annotated_img, f"{class_name} {conf:.2f}", (x1, y1 - 10),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)

            # Save the annotated image
            annotated_img_path = img_path.replace(".jpg", "_annotated.jpg")
            cv2.imwrite(annotated_img_path, annotated_img)
            item["detected_components_by_image"][img_path] = {
                "annotated_image_path": annotated_img_path,
                "detections": detected_components,
                "door_found": door_found_in_image
            }

        # Aggregate door counts (deduplicate if same door detected across multiple frames of one wagon)
        # This is complex and might need a separate tracking algorithm. For simplicity, just sum per image for report.
        item["total_doors_open_in_wagon"] = door_open_count
        item["total_doors_closed_in_wagon"] = door_closed_count
        item["door_open_status_flag"] = "Yes" if door_open_count > 0 else "No"

logger.info("--- Full coverage image extraction and object detection complete. ---")
# Out:
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_1/extracted_frames/12309_wagon_1_1.jpg: 288x640 1 train, 1 truck, 276.8ms
# Speed: 7.7ms preprocess, 276.8ms inference, 33.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_1/extracted_frames/12309_wagon_1_2.jpg: 288x640 1 bus, 1 train, 1 truck, 104.7ms
# Speed: 2.1ms preprocess, 104.7ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_1/extracted_frames/12309_wagon_1_3.jpg: 288x640 2 trains, 114.5ms
# Speed: 2.1ms preprocess, 114.5ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_1/extracted_frames/12309_wagon_1_4.jpg: 288x640 2 trains, 103.1ms
# Speed: 2.0ms preprocess, 103.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_1/extracted_frames/12309_wagon_1_5.jpg: 288x640 2 trains, 103.5ms
# Speed: 2.1ms preprocess, 103.5ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_2/extracted_frames/12309_wagon_2_1.jpg: 288x640 2 trains, 106.8ms
# Speed: 2.1ms preprocess, 106.8ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_3/extracted_frames/12309_wagon_3_1.jpg: 288x640 2 trains, 102.9ms
# Speed: 2.2ms preprocess, 102.9ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_4/extracted_frames/12309_wagon_4_1.jpg: 288x640 2 trains, 106.1ms
# Speed: 2.1ms preprocess, 106.1ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_5/extracted_frames/12309_wagon_5_1.jpg: 288x640 2 trains, 119.9ms
# Speed: 2.0ms preprocess, 119.9ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_6/extracted_frames/12309_wagon_6_1.jpg: 288x640 2 trains, 101.8ms
# Speed: 2.1ms preprocess, 101.8ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_6/extracted_frames/12309_wagon_6_2.jpg: 288x640 1 train, 110.6ms
# Speed: 2.1ms preprocess, 110.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_6/extracted_frames/12309_wagon_6_3.jpg: 288x640 2 trains, 103.4ms
# Speed: 2.1ms preprocess, 103.4ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_6/extracted_frames/12309_wagon_6_4.jpg: 288x640 2 trains, 103.2ms
# Speed: 2.1ms preprocess, 103.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_7/extracted_frames/12309_wagon_7_1.jpg: 288x640 1 train, 108.0ms
# Speed: 2.0ms preprocess, 108.0ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_8/extracted_frames/12309_wagon_8_1.jpg: 288x640 2 trains, 102.9ms
# Speed: 2.1ms preprocess, 102.9ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_8/extracted_frames/12309_wagon_8_2.jpg: 288x640 1 person, 1 train, 118.1ms
# Speed: 2.1ms preprocess, 118.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_8/extracted_frames/12309_wagon_8_3.jpg: 288x640 1 airplane, 2 trains, 103.9ms
# Speed: 2.2ms preprocess, 103.9ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_8/extracted_frames/12309_wagon_8_4.jpg: 288x640 1 person, 2 trains, 105.9ms
# Speed: 2.0ms preprocess, 105.9ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_8/extracted_frames/12309_wagon_8_5.jpg: 288x640 1 airplane, 1 train, 101.7ms
# Speed: 2.0ms preprocess, 101.7ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_9/extracted_frames/12309_wagon_9_1.jpg: 288x640 2 trains, 103.1ms
# Speed: 2.1ms preprocess, 103.1ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_10/extracted_frames/12309_wagon_10_1.jpg: 288x640 2 trains, 104.5ms
# Speed: 2.5ms preprocess, 104.5ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_11/extracted_frames/12309_wagon_11_1.jpg: 288x640 2 trains, 115.2ms
# Speed: 2.1ms preprocess, 115.2ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_12/extracted_frames/12309_wagon_12_1.jpg: 288x640 2 trains, 104.9ms
# Speed: 2.0ms preprocess, 104.9ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_13/extracted_frames/12309_wagon_13_1.jpg: 288x640 2 trains, 109.3ms
# Speed: 2.9ms preprocess, 109.3ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_13/extracted_frames/12309_wagon_13_2.jpg: 288x640 1 train, 104.3ms
# Speed: 2.1ms preprocess, 104.3ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_13/extracted_frames/12309_wagon_13_3.jpg: 288x640 1 airplane, 102.8ms
# Speed: 2.4ms preprocess, 102.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_13/extracted_frames/12309_wagon_13_4.jpg: 288x640 2 trains, 104.6ms
# Speed: 2.0ms preprocess, 104.6ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_13/extracted_frames/12309_wagon_13_5.jpg: 288x640 2 trains, 103.6ms
# Speed: 2.0ms preprocess, 103.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_14/extracted_frames/12309_wagon_14_1.jpg: 288x640 1 airplane, 1 train, 103.1ms
# Speed: 2.1ms preprocess, 103.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_14/extracted_frames/12309_wagon_14_2.jpg: 288x640 1 airplane, 1 train, 107.0ms
# Speed: 2.0ms preprocess, 107.0ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_14/extracted_frames/12309_wagon_14_3.jpg: 288x640 2 trains, 102.3ms
# Speed: 2.0ms preprocess, 102.3ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_14/extracted_frames/12309_wagon_14_4.jpg: 288x640 2 trains, 1 truck, 102.8ms
# Speed: 2.0ms preprocess, 102.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_15/extracted_frames/12309_wagon_15_1.jpg: 288x640 2 trains, 105.1ms
# Speed: 2.2ms preprocess, 105.1ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_16/extracted_frames/12309_wagon_16_1.jpg: 288x640 2 trains, 1 tv, 103.4ms
# Speed: 2.1ms preprocess, 103.4ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_17/extracted_frames/12309_wagon_17_1.jpg: 288x640 3 trains, 122.5ms
# Speed: 2.1ms preprocess, 122.5ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_18/extracted_frames/12309_wagon_18_1.jpg: 288x640 2 trains, 107.0ms
# Speed: 2.3ms preprocess, 107.0ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_19/extracted_frames/12309_wagon_19_1.jpg: 288x640 2 trains, 101.7ms
# Speed: 2.1ms preprocess, 101.7ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_20/extracted_frames/12309_wagon_20_1.jpg: 288x640 2 trains, 104.1ms
# Speed: 2.1ms preprocess, 104.1ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_21/extracted_frames/12309_wagon_21_1.jpg: 288x640 1 train, 103.8ms
# Speed: 2.1ms preprocess, 103.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_22/extracted_frames/12309_wagon_22_1.jpg: 288x640 1 train, 105.7ms
# Speed: 2.1ms preprocess, 105.7ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_23/extracted_frames/12309_wagon_23_1.jpg: 288x640 2 trains, 127.7ms
# Speed: 5.2ms preprocess, 127.7ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_24/extracted_frames/12309_wagon_24_1.jpg: 288x640 1 train, 1 truck, 100.6ms
# Speed: 2.2ms preprocess, 100.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_25/extracted_frames/12309_wagon_25_1.jpg: 288x640 2 trains, 102.0ms
# Speed: 2.0ms preprocess, 102.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_26/extracted_frames/12309_wagon_26_1.jpg: 288x640 1 train, 102.6ms
# Speed: 2.0ms preprocess, 102.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_27/extracted_frames/12309_wagon_27_1.jpg: 288x640 1 bus, 2 trains, 101.8ms
# Speed: 2.1ms preprocess, 101.8ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_28/extracted_frames/12309_wagon_28_1.jpg: 288x640 1 bus, 1 train, 103.6ms
# Speed: 2.1ms preprocess, 103.6ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_29/extracted_frames/12309_wagon_29_1.jpg: 288x640 2 trains, 166.7ms
# Speed: 3.1ms preprocess, 166.7ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_30/extracted_frames/12309_wagon_30_1.jpg: 288x640 2 trains, 1 truck, 155.5ms
# Speed: 2.9ms preprocess, 155.5ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_31/extracted_frames/12309_wagon_31_1.jpg: 288x640 1 train, 1 truck, 155.5ms
# Speed: 2.9ms preprocess, 155.5ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_32/extracted_frames/12309_wagon_32_1.jpg: 288x640 1 train, 156.8ms
# Speed: 2.9ms preprocess, 156.8ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_33/extracted_frames/12309_wagon_33_1.jpg: 288x640 1 bus, 1 train, 158.4ms
# Speed: 3.1ms preprocess, 158.4ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_34/extracted_frames/12309_wagon_34_1.jpg: 288x640 2 trains, 156.6ms
# Speed: 3.1ms preprocess, 156.6ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_35/extracted_frames/12309_wagon_35_1.jpg: 288x640 2 trains, 158.9ms
# Speed: 3.5ms preprocess, 158.9ms inference, 2.8ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_36/extracted_frames/12309_wagon_36_1.jpg: 288x640 1 train, 1 truck, 163.5ms
# Speed: 3.0ms preprocess, 163.5ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_37/extracted_frames/12309_wagon_37_1.jpg: 288x640 1 train, 166.6ms
# Speed: 3.1ms preprocess, 166.6ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_38/extracted_frames/12309_wagon_38_1.jpg: 288x640 2 trains, 154.7ms
# Speed: 2.9ms preprocess, 154.7ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_39/extracted_frames/12309_wagon_39_1.jpg: 288x640 2 trains, 107.2ms
# Speed: 2.0ms preprocess, 107.2ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_40/extracted_frames/12309_wagon_40_1.jpg: 288x640 2 trains, 102.9ms
# Speed: 2.2ms preprocess, 102.9ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_41/extracted_frames/12309_wagon_41_1.jpg: 288x640 2 trains, 100.4ms
# Speed: 2.1ms preprocess, 100.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_42/extracted_frames/12309_wagon_42_1.jpg: 288x640 1 train, 102.4ms
# Speed: 2.1ms preprocess, 102.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_43/extracted_frames/12309_wagon_43_1.jpg: 288x640 1 train, 1 truck, 105.8ms
# Speed: 2.2ms preprocess, 105.8ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_44/extracted_frames/12309_wagon_44_1.jpg: 288x640 2 trains, 104.6ms
# Speed: 2.2ms preprocess, 104.6ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_45/extracted_frames/12309_wagon_45_1.jpg: 288x640 2 trains, 102.2ms
# Speed: 2.3ms preprocess, 102.2ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_46/extracted_frames/12309_wagon_46_1.jpg: 288x640 1 train, 105.5ms
# Speed: 2.0ms preprocess, 105.5ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_47/extracted_frames/12309_wagon_47_1.jpg: 288x640 1 train, 114.0ms
# Speed: 2.0ms preprocess, 114.0ms inference, 3.0ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_48/extracted_frames/12309_wagon_48_1.jpg: 288x640 2 trains, 103.6ms
# Speed: 2.1ms preprocess, 103.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_49/extracted_frames/12309_wagon_49_1.jpg: 288x640 1 train, 1 truck, 104.5ms
# Speed: 2.0ms preprocess, 104.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_50/extracted_frames/12309_wagon_50_1.jpg: 288x640 1 train, 1 boat, 102.0ms
# Speed: 2.0ms preprocess, 102.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_51/extracted_frames/12309_wagon_51_1.jpg: 288x640 1 train, 1 truck, 1 boat, 101.7ms
# Speed: 2.0ms preprocess, 101.7ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_52/extracted_frames/12309_wagon_52_1.jpg: 288x640 2 trains, 99.8ms
# Speed: 2.0ms preprocess, 99.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_53/extracted_frames/12309_wagon_53_1.jpg: 288x640 1 bus, 1 train, 119.4ms
# Speed: 2.1ms preprocess, 119.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_54/extracted_frames/12309_wagon_54_1.jpg: 288x640 2 trains, 105.9ms
# Speed: 2.1ms preprocess, 105.9ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_55/extracted_frames/12309_wagon_55_1.jpg: 288x640 1 person, 1 bus, 1 train, 108.2ms
# Speed: 2.0ms preprocess, 108.2ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_56/extracted_frames/12309_wagon_56_1.jpg: 288x640 2 trains, 1 truck, 104.4ms
# Speed: 2.2ms preprocess, 104.4ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_57/extracted_frames/12309_wagon_57_1.jpg: 288x640 1 train, 1 truck, 114.2ms
# Speed: 2.1ms preprocess, 114.2ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_58/extracted_frames/12309_wagon_58_1.jpg: 288x640 2 trains, 106.1ms
# Speed: 2.1ms preprocess, 106.1ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_59/extracted_frames/12309_wagon_59_1.jpg: 288x640 1 train, 115.9ms
# Speed: 2.9ms preprocess, 115.9ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_60/extracted_frames/12309_wagon_60_1.jpg: 288x640 1 train, 103.1ms
# Speed: 2.2ms preprocess, 103.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_61/extracted_frames/12309_wagon_61_1.jpg: 288x640 1 train, 1 truck, 103.4ms
# Speed: 2.2ms preprocess, 103.4ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_62/extracted_frames/12309_wagon_62_1.jpg: 288x640 1 train, 1 truck, 101.1ms
# Speed: 2.0ms preprocess, 101.1ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_63/extracted_frames/12309_wagon_63_1.jpg: 288x640 2 trains, 1 truck, 103.6ms
# Speed: 2.0ms preprocess, 103.6ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_64/extracted_frames/12309_wagon_64_1.jpg: 288x640 1 train, 104.1ms
# Speed: 2.1ms preprocess, 104.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_65/extracted_frames/12309_wagon_65_1.jpg: 288x640 2 trains, 104.4ms
# Speed: 2.0ms preprocess, 104.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_66/extracted_frames/12309_wagon_66_1.jpg: 288x640 1 train, 104.0ms
# Speed: 2.1ms preprocess, 104.0ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_67/extracted_frames/12309_wagon_67_1.jpg: 288x640 1 train, 102.3ms
# Speed: 2.1ms preprocess, 102.3ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_68/extracted_frames/12309_wagon_68_1.jpg: 288x640 1 train, 1 truck, 110.3ms
# Speed: 2.0ms preprocess, 110.3ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_69/extracted_frames/12309_wagon_69_1.jpg: 288x640 1 train, 1 truck, 102.8ms
# Speed: 2.0ms preprocess, 102.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_70/extracted_frames/12309_wagon_70_1.jpg: 288x640 2 trains, 1 truck, 120.5ms
# Speed: 2.1ms preprocess, 120.5ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_71/extracted_frames/12309_wagon_71_1.jpg: 288x640 2 trains, 105.2ms
# Speed: 2.1ms preprocess, 105.2ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_72/extracted_frames/12309_wagon_72_1.jpg: 288x640 1 train, 114.4ms
# Speed: 2.1ms preprocess, 114.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_73/extracted_frames/12309_wagon_73_1.jpg: 288x640 2 trains, 103.1ms
# Speed: 2.1ms preprocess, 103.1ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_73/extracted_frames/12309_wagon_73_2.jpg: 288x640 1 train, 122.3ms
# Speed: 2.0ms preprocess, 122.3ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_73/extracted_frames/12309_wagon_73_3.jpg: 288x640 1 train, 103.2ms
# Speed: 2.0ms preprocess, 103.2ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_73/extracted_frames/12309_wagon_73_4.jpg: 288x640 1 train, 102.0ms
# Speed: 2.0ms preprocess, 102.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_74/extracted_frames/12309_wagon_74_1.jpg: 288x640 1 train, 1 truck, 105.0ms
# Speed: 2.1ms preprocess, 105.0ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_75/extracted_frames/12309_wagon_75_1.jpg: 288x640 1 bus, 1 train, 104.5ms
# Speed: 2.1ms preprocess, 104.5ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_76/extracted_frames/12309_wagon_76_1.jpg: 288x640 1 bus, 1 train, 104.1ms
# Speed: 2.1ms preprocess, 104.1ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_77/extracted_frames/12309_wagon_77_1.jpg: 288x640 1 bus, 1 train, 119.4ms
# Speed: 2.1ms preprocess, 119.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_78/extracted_frames/12309_wagon_78_1.jpg: 288x640 1 train, 104.5ms
# Speed: 2.1ms preprocess, 104.5ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_79/extracted_frames/12309_wagon_79_1.jpg: 288x640 2 trains, 101.2ms
# Speed: 2.0ms preprocess, 101.2ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_80/extracted_frames/12309_wagon_80_1.jpg: 288x640 1 train, 106.8ms
# Speed: 2.1ms preprocess, 106.8ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_81/extracted_frames/12309_wagon_81_1.jpg: 288x640 1 train, 102.0ms
# Speed: 2.1ms preprocess, 102.0ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_82/extracted_frames/12309_wagon_82_1.jpg: 288x640 1 bus, 1 train, 103.8ms
# Speed: 2.1ms preprocess, 103.8ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_83/extracted_frames/12309_wagon_83_1.jpg: 288x640 1 bus, 2 trains, 115.0ms
# Speed: 2.9ms preprocess, 115.0ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_84/extracted_frames/12309_wagon_84_1.jpg: 288x640 1 train, 104.8ms
# Speed: 2.0ms preprocess, 104.8ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_85/extracted_frames/12309_wagon_85_1.jpg: 288x640 2 trains, 101.8ms
# Speed: 2.1ms preprocess, 101.8ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_86/extracted_frames/12309_wagon_86_1.jpg: 288x640 1 train, 103.2ms
# Speed: 2.1ms preprocess, 103.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_87/extracted_frames/12309_wagon_87_1.jpg: 288x640 (no detections), 108.0ms
# Speed: 2.1ms preprocess, 108.0ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_88/extracted_frames/12309_wagon_88_1.jpg: 288x640 1 bus, 1 train, 102.3ms
# Speed: 2.1ms preprocess, 102.3ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_89/extracted_frames/12309_wagon_89_1.jpg: 288x640 2 trains, 168.8ms
# Speed: 2.9ms preprocess, 168.8ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_90/extracted_frames/12309_wagon_90_1.jpg: 288x640 1 train, 167.6ms
# Speed: 3.4ms preprocess, 167.6ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_91/extracted_frames/12309_wagon_91_1.jpg: 288x640 1 train, 159.8ms
# Speed: 2.9ms preprocess, 159.8ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_92/extracted_frames/12309_wagon_92_1.jpg: 288x640 1 train, 166.8ms
# Speed: 2.9ms preprocess, 166.8ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_93/extracted_frames/12309_wagon_93_1.jpg: 288x640 1 train, 164.3ms
# Speed: 3.6ms preprocess, 164.3ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_94/extracted_frames/12309_wagon_94_1.jpg: 288x640 2 trains, 158.8ms
# Speed: 3.0ms preprocess, 158.8ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_95/extracted_frames/12309_wagon_95_1.jpg: 288x640 1 bus, 1 train, 157.1ms
# Speed: 3.0ms preprocess, 157.1ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_96/extracted_frames/12309_wagon_96_1.jpg: 288x640 2 trains, 187.9ms
# Speed: 3.1ms preprocess, 187.9ms inference, 8.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_97/extracted_frames/12309_wagon_97_1.jpg: 288x640 2 trains, 171.0ms
# Speed: 2.9ms preprocess, 171.0ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_98/extracted_frames/12309_wagon_98_1.jpg: 288x640 1 train, 162.7ms
# Speed: 2.9ms preprocess, 162.7ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_99/extracted_frames/12309_wagon_99_1.jpg: 288x640 1 train, 102.1ms
# Speed: 2.1ms preprocess, 102.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_100/extracted_frames/12309_wagon_100_1.jpg: 288x640 2 trains, 1 truck, 102.3ms
# Speed: 2.0ms preprocess, 102.3ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_101/extracted_frames/12309_wagon_101_1.jpg: 288x640 1 train, 1 truck, 102.1ms
# Speed: 2.8ms preprocess, 102.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_102/extracted_frames/12309_wagon_102_1.jpg: 288x640 2 trains, 103.4ms
# Speed: 2.1ms preprocess, 103.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_103/extracted_frames/12309_wagon_103_1.jpg: 288x640 1 train, 103.8ms
# Speed: 2.1ms preprocess, 103.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_104/extracted_frames/12309_wagon_104_1.jpg: 288x640 2 trains, 102.4ms
# Speed: 1.9ms preprocess, 102.4ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_105/extracted_frames/12309_wagon_105_1.jpg: 288x640 1 train, 104.3ms
# Speed: 2.0ms preprocess, 104.3ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_106/extracted_frames/12309_wagon_106_1.jpg: 288x640 2 trains, 102.7ms
# Speed: 2.0ms preprocess, 102.7ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_107/extracted_frames/12309_wagon_107_1.jpg: 288x640 1 train, 1 truck, 101.5ms
# Speed: 2.1ms preprocess, 101.5ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_108/extracted_frames/12309_wagon_108_1.jpg: 288x640 1 train, 103.4ms
# Speed: 2.1ms preprocess, 103.4ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_109/extracted_frames/12309_wagon_109_1.jpg: 288x640 1 train, 1 boat, 102.1ms
# Speed: 1.9ms preprocess, 102.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_110/extracted_frames/12309_wagon_110_1.jpg: 288x640 2 trains, 102.3ms
# Speed: 2.1ms preprocess, 102.3ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_111/extracted_frames/12309_wagon_111_1.jpg: 288x640 2 trains, 102.9ms
# Speed: 2.1ms preprocess, 102.9ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_112/extracted_frames/12309_wagon_112_1.jpg: 288x640 2 trains, 117.8ms
# Speed: 2.3ms preprocess, 117.8ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_113/extracted_frames/12309_wagon_113_1.jpg: 288x640 1 train, 102.8ms
# Speed: 2.1ms preprocess, 102.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_114/extracted_frames/12309_wagon_114_1.jpg: 288x640 (no detections), 103.3ms
# Speed: 2.0ms preprocess, 103.3ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_115/extracted_frames/12309_wagon_115_1.jpg: 288x640 1 truck, 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_116/extracted_frames/12309_wagon_116_1.jpg: 288x640 1 truck, 104.8ms
# Speed: 2.0ms preprocess, 104.8ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_117/extracted_frames/12309_wagon_117_1.jpg: 288x640 (no detections), 292.9ms
# Speed: 2.9ms preprocess, 292.9ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_118/extracted_frames/12309_wagon_118_1.jpg: 288x640 1 train, 154.1ms
# Speed: 2.9ms preprocess, 154.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_119/extracted_frames/12309_wagon_119_1.jpg: 288x640 1 bus, 1 train, 101.8ms
# Speed: 2.0ms preprocess, 101.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_120/extracted_frames/12309_wagon_120_1.jpg: 288x640 1 bus, 2 trains, 107.0ms
# Speed: 2.1ms preprocess, 107.0ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_121/extracted_frames/12309_wagon_121_1.jpg: 288x640 2 trains, 103.2ms
# Speed: 2.1ms preprocess, 103.2ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_122/extracted_frames/12309_wagon_122_1.jpg: 288x640 1 train, 121.5ms
# Speed: 2.9ms preprocess, 121.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_123/extracted_frames/12309_wagon_123_1.jpg: 288x640 2 trains, 101.2ms
# Speed: 2.0ms preprocess, 101.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_124/extracted_frames/12309_wagon_124_1.jpg: 288x640 2 trains, 102.2ms
# Speed: 2.0ms preprocess, 102.2ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_125/extracted_frames/12309_wagon_125_1.jpg: 288x640 2 trains, 102.6ms
# Speed: 2.0ms preprocess, 102.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_126/extracted_frames/12309_wagon_126_1.jpg: 288x640 2 trains, 105.1ms
# Speed: 2.0ms preprocess, 105.1ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_127/extracted_frames/12309_wagon_127_1.jpg: 288x640 2 trains, 106.4ms
# Speed: 2.0ms preprocess, 106.4ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_128/extracted_frames/12309_wagon_128_1.jpg: 288x640 2 trains, 121.6ms
# Speed: 3.0ms preprocess, 121.6ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_129/extracted_frames/12309_wagon_129_1.jpg: 288x640 2 trains, 103.6ms
# Speed: 2.0ms preprocess, 103.6ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_130/extracted_frames/12309_wagon_130_1.jpg: 288x640 1 bus, 2 trains, 103.7ms
# Speed: 2.0ms preprocess, 103.7ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_131/extracted_frames/12309_wagon_131_1.jpg: 288x640 2 trains, 104.5ms
# Speed: 2.0ms preprocess, 104.5ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_132/extracted_frames/12309_wagon_132_1.jpg: 288x640 2 trains, 102.8ms
# Speed: 2.1ms preprocess, 102.8ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_133/extracted_frames/12309_wagon_133_1.jpg: 288x640 2 trains, 103.6ms
# Speed: 2.1ms preprocess, 103.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_134/extracted_frames/12309_wagon_134_1.jpg: 288x640 1 train, 102.4ms
# Speed: 2.2ms preprocess, 102.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_135/extracted_frames/12309_wagon_135_1.jpg: 288x640 2 trains, 103.2ms
# Speed: 2.2ms preprocess, 103.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_136/extracted_frames/12309_wagon_136_1.jpg: 288x640 1 train, 104.4ms
# Speed: 2.1ms preprocess, 104.4ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_137/extracted_frames/12309_wagon_137_1.jpg: 288x640 2 trains, 101.9ms
# Speed: 2.0ms preprocess, 101.9ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_138/extracted_frames/12309_wagon_138_1.jpg: 288x640 1 train, 100.9ms
# Speed: 2.0ms preprocess, 100.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_139/extracted_frames/12309_wagon_139_1.jpg: 288x640 1 train, 120.7ms
# Speed: 2.0ms preprocess, 120.7ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_140/extracted_frames/12309_wagon_140_1.jpg: 288x640 1 train, 101.9ms
# Speed: 2.0ms preprocess, 101.9ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_141/extracted_frames/12309_wagon_141_1.jpg: 288x640 1 train, 104.1ms
# Speed: 2.2ms preprocess, 104.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_142/extracted_frames/12309_wagon_142_1.jpg: 288x640 1 train, 105.8ms
# Speed: 2.1ms preprocess, 105.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_143/extracted_frames/12309_wagon_143_1.jpg: 288x640 1 train, 109.0ms
# Speed: 2.1ms preprocess, 109.0ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_144/extracted_frames/12309_wagon_144_1.jpg: 288x640 1 bus, 1 train, 1 truck, 103.3ms
# Speed: 2.3ms preprocess, 103.3ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_144/extracted_frames/12309_wagon_144_2.jpg: 288x640 1 bus, 1 train, 1 truck, 107.4ms
# Speed: 2.8ms preprocess, 107.4ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_145/extracted_frames/12309_wagon_145_1.jpg: 288x640 1 bus, 1 train, 105.9ms
# Speed: 2.0ms preprocess, 105.9ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_146/extracted_frames/12309_wagon_146_1.jpg: 288x640 1 train, 105.6ms
# Speed: 2.0ms preprocess, 105.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_147/extracted_frames/12309_wagon_147_1.jpg: 288x640 1 train, 107.6ms
# Speed: 2.2ms preprocess, 107.6ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_148/extracted_frames/12309_wagon_148_1.jpg: 288x640 (no detections), 111.0ms
# Speed: 2.0ms preprocess, 111.0ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_149/extracted_frames/12309_wagon_149_1.jpg: 288x640 (no detections), 104.1ms
# Speed: 2.1ms preprocess, 104.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_150/extracted_frames/12309_wagon_150_1.jpg: 288x640 1 bus, 1 train, 106.0ms
# Speed: 2.1ms preprocess, 106.0ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_151/extracted_frames/12309_wagon_151_1.jpg: 288x640 1 train, 168.8ms
# Speed: 2.9ms preprocess, 168.8ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_152/extracted_frames/12309_wagon_152_1.jpg: 288x640 1 train, 161.7ms
# Speed: 3.0ms preprocess, 161.7ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_153/extracted_frames/12309_wagon_153_1.jpg: 288x640 1 train, 157.8ms
# Speed: 3.0ms preprocess, 157.8ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_154/extracted_frames/12309_wagon_154_1.jpg: 288x640 1 train, 1 clock, 160.1ms
# Speed: 4.9ms preprocess, 160.1ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_155/extracted_frames/12309_wagon_155_1.jpg: 288x640 1 train, 158.6ms
# Speed: 3.1ms preprocess, 158.6ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_156/extracted_frames/12309_wagon_156_1.jpg: 288x640 1 train, 156.4ms
# Speed: 3.0ms preprocess, 156.4ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_157/extracted_frames/12309_wagon_157_1.jpg: 288x640 1 train, 1 truck, 162.9ms
# Speed: 3.5ms preprocess, 162.9ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_158/extracted_frames/12309_wagon_158_1.jpg: 288x640 2 trains, 160.4ms
# Speed: 4.9ms preprocess, 160.4ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_159/extracted_frames/12309_wagon_159_1.jpg: 288x640 1 train, 165.5ms
# Speed: 3.3ms preprocess, 165.5ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_160/extracted_frames/12309_wagon_160_1.jpg: 288x640 1 bus, 2 trains, 156.3ms
# Speed: 3.1ms preprocess, 156.3ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_161/extracted_frames/12309_wagon_161_1.jpg: 288x640 1 train, 104.6ms
# Speed: 2.1ms preprocess, 104.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_162/extracted_frames/12309_wagon_162_1.jpg: 288x640 (no detections), 117.0ms
# Speed: 2.0ms preprocess, 117.0ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_163/extracted_frames/12309_wagon_163_1.jpg: 288x640 (no detections), 106.7ms
# Speed: 2.2ms preprocess, 106.7ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_164/extracted_frames/12309_wagon_164_1.jpg: 288x640 1 train, 101.7ms
# Speed: 2.0ms preprocess, 101.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_165/extracted_frames/12309_wagon_165_1.jpg: 288x640 2 trains, 105.7ms
# Speed: 2.0ms preprocess, 105.7ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_166/extracted_frames/12309_wagon_166_1.jpg: 288x640 2 trains, 102.8ms
# Speed: 2.1ms preprocess, 102.8ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_167/extracted_frames/12309_wagon_167_1.jpg: 288x640 1 train, 105.4ms
# Speed: 2.0ms preprocess, 105.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_168/extracted_frames/12309_wagon_168_1.jpg: 288x640 1 train, 102.5ms
# Speed: 2.1ms preprocess, 102.5ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_169/extracted_frames/12309_wagon_169_1.jpg: 288x640 1 train, 1 truck, 105.1ms
# Speed: 2.1ms preprocess, 105.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_170/extracted_frames/12309_wagon_170_1.jpg: 288x640 2 trains, 102.5ms
# Speed: 2.0ms preprocess, 102.5ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_171/extracted_frames/12309_wagon_171_1.jpg: 288x640 1 bus, 1 train, 1 truck, 131.3ms
# Speed: 2.1ms preprocess, 131.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_172/extracted_frames/12309_wagon_172_1.jpg: 288x640 1 train, 102.9ms
# Speed: 2.1ms preprocess, 102.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_173/extracted_frames/12309_wagon_173_1.jpg: 288x640 1 train, 118.5ms
# Speed: 2.0ms preprocess, 118.5ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_174/extracted_frames/12309_wagon_174_1.jpg: 288x640 1 train, 105.4ms
# Speed: 2.4ms preprocess, 105.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_175/extracted_frames/12309_wagon_175_1.jpg: 288x640 1 train, 109.1ms
# Speed: 2.8ms preprocess, 109.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_176/extracted_frames/12309_wagon_176_1.jpg: 288x640 1 train, 101.7ms
# Speed: 2.2ms preprocess, 101.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_177/extracted_frames/12309_wagon_177_1.jpg: 288x640 1 bus, 2 trains, 101.9ms
# Speed: 2.0ms preprocess, 101.9ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_178/extracted_frames/12309_wagon_178_1.jpg: 288x640 1 train, 1 truck, 101.1ms
# Speed: 2.0ms preprocess, 101.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_179/extracted_frames/12309_wagon_179_1.jpg: 288x640 1 bus, 2 trains, 103.5ms
# Speed: 2.6ms preprocess, 103.5ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_180/extracted_frames/12309_wagon_180_1.jpg: 288x640 2 trains, 101.1ms
# Speed: 2.1ms preprocess, 101.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_181/extracted_frames/12309_wagon_181_1.jpg: 288x640 2 trains, 103.5ms
# Speed: 2.1ms preprocess, 103.5ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# ...
# Speed: 2.1ms preprocess, 103.1ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_318/extracted_frames/12309_wagon_318_1.jpg: 288x640 1 train, 103.2ms
# Speed: 2.1ms preprocess, 103.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_319/extracted_frames/12309_wagon_319_1.jpg: 288x640 1 train, 123.2ms
# Speed: 2.2ms preprocess, 123.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_320/extracted_frames/12309_wagon_320_1.jpg: 288x640 1 train, 102.1ms
# Speed: 2.1ms preprocess, 102.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_321/extracted_frames/12309_wagon_321_1.jpg: 288x640 (no detections), 108.8ms
# Speed: 2.1ms preprocess, 108.8ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_322/extracted_frames/12309_wagon_322_1.jpg: 288x640 1 train, 102.7ms
# Speed: 2.1ms preprocess, 102.7ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_323/extracted_frames/12309_wagon_323_1.jpg: 288x640 1 bus, 1 train, 103.8ms
# Speed: 2.1ms preprocess, 103.8ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_324/extracted_frames/12309_wagon_324_1.jpg: 288x640 1 train, 103.4ms
# Speed: 2.0ms preprocess, 103.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_325/extracted_frames/12309_wagon_325_1.jpg: 288x640 1 truck, 108.9ms
# Speed: 3.2ms preprocess, 108.9ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_326/extracted_frames/12309_wagon_326_1.jpg: 288x640 1 train, 1 truck, 1 boat, 104.0ms
# Speed: 2.3ms preprocess, 104.0ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_327/extracted_frames/12309_wagon_327_1.jpg: 288x640 (no detections), 106.1ms
# Speed: 2.0ms preprocess, 106.1ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_328/extracted_frames/12309_wagon_328_1.jpg: 288x640 (no detections), 103.1ms
# Speed: 2.1ms preprocess, 103.1ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_329/extracted_frames/12309_wagon_329_1.jpg: 288x640 1 train, 102.6ms
# Speed: 2.1ms preprocess, 102.6ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_330/extracted_frames/12309_wagon_330_1.jpg: 288x640 1 train, 122.1ms
# Speed: 2.1ms preprocess, 122.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_331/extracted_frames/12309_wagon_331_1.jpg: 288x640 1 train, 102.6ms
# Speed: 2.0ms preprocess, 102.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_332/extracted_frames/12309_wagon_332_1.jpg: 288x640 2 trains, 108.3ms
# Speed: 2.1ms preprocess, 108.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_333/extracted_frames/12309_wagon_333_1.jpg: 288x640 1 boat, 104.7ms
# Speed: 2.1ms preprocess, 104.7ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_334/extracted_frames/12309_wagon_334_1.jpg: 288x640 1 train, 102.9ms
# Speed: 2.3ms preprocess, 102.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_335/extracted_frames/12309_wagon_335_1.jpg: 288x640 1 bus, 110.4ms
# Speed: 2.1ms preprocess, 110.4ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_336/extracted_frames/12309_wagon_336_1.jpg: 288x640 (no detections), 114.0ms
# Speed: 2.8ms preprocess, 114.0ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_337/extracted_frames/12309_wagon_337_1.jpg: 288x640 1 train, 105.6ms
# Speed: 2.2ms preprocess, 105.6ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_338/extracted_frames/12309_wagon_338_1.jpg: 288x640 1 train, 104.1ms
# Speed: 2.2ms preprocess, 104.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_339/extracted_frames/12309_wagon_339_1.jpg: 288x640 (no detections), 103.5ms
# Speed: 2.1ms preprocess, 103.5ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_340/extracted_frames/12309_wagon_340_1.jpg: 288x640 (no detections), 178.2ms
# Speed: 3.0ms preprocess, 178.2ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_341/extracted_frames/12309_wagon_341_1.jpg: 288x640 (no detections), 172.1ms
# Speed: 5.0ms preprocess, 172.1ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_342/extracted_frames/12309_wagon_342_1.jpg: 288x640 2 trains, 166.0ms
# Speed: 3.4ms preprocess, 166.0ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_343/extracted_frames/12309_wagon_343_1.jpg: 288x640 2 trains, 1 clock, 160.1ms
# Speed: 2.9ms preprocess, 160.1ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_344/extracted_frames/12309_wagon_344_1.jpg: 288x640 (no detections), 167.1ms
# Speed: 2.9ms preprocess, 167.1ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_345/extracted_frames/12309_wagon_345_1.jpg: 288x640 1 train, 179.8ms
# Speed: 4.6ms preprocess, 179.8ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_346/extracted_frames/12309_wagon_346_1.jpg: 288x640 1 train, 158.6ms
# Speed: 2.9ms preprocess, 158.6ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_347/extracted_frames/12309_wagon_347_1.jpg: 288x640 1 train, 173.8ms
# Speed: 3.0ms preprocess, 173.8ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_348/extracted_frames/12309_wagon_348_1.jpg: 288x640 2 trains, 168.7ms
# Speed: 2.9ms preprocess, 168.7ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_349/extracted_frames/12309_wagon_349_1.jpg: 288x640 (no detections), 168.0ms
# Speed: 5.1ms preprocess, 168.0ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_350/extracted_frames/12309_wagon_350_1.jpg: 288x640 1 train, 103.9ms
# Speed: 2.1ms preprocess, 103.9ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_351/extracted_frames/12309_wagon_351_1.jpg: 288x640 1 train, 106.8ms
# Speed: 2.6ms preprocess, 106.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_352/extracted_frames/12309_wagon_352_1.jpg: 288x640 1 train, 1 boat, 105.3ms
# Speed: 2.2ms preprocess, 105.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_353/extracted_frames/12309_wagon_353_1.jpg: 288x640 1 train, 103.0ms
# Speed: 2.1ms preprocess, 103.0ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_354/extracted_frames/12309_wagon_354_1.jpg: 288x640 1 train, 105.1ms
# Speed: 2.2ms preprocess, 105.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_355/extracted_frames/12309_wagon_355_1.jpg: 288x640 1 train, 105.0ms
# Speed: 2.1ms preprocess, 105.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_356/extracted_frames/12309_wagon_356_1.jpg: 288x640 1 train, 104.1ms
# Speed: 2.0ms preprocess, 104.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_357/extracted_frames/12309_wagon_357_1.jpg: 288x640 (no detections), 111.6ms
# Speed: 2.1ms preprocess, 111.6ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_358/extracted_frames/12309_wagon_358_1.jpg: 288x640 (no detections), 102.7ms
# Speed: 2.1ms preprocess, 102.7ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_359/extracted_frames/12309_wagon_359_1.jpg: 288x640 (no detections), 123.6ms
# Speed: 2.0ms preprocess, 123.6ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_360/extracted_frames/12309_wagon_360_1.jpg: 288x640 1 train, 112.5ms
# Speed: 2.2ms preprocess, 112.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_361/extracted_frames/12309_wagon_361_1.jpg: 288x640 1 traffic light, 105.4ms
# Speed: 2.5ms preprocess, 105.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_362/extracted_frames/12309_wagon_362_1.jpg: 288x640 1 train, 105.8ms
# Speed: 2.4ms preprocess, 105.8ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_363/extracted_frames/12309_wagon_363_1.jpg: 288x640 1 train, 102.7ms
# Speed: 2.1ms preprocess, 102.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_364/extracted_frames/12309_wagon_364_1.jpg: 288x640 (no detections), 105.1ms
# Speed: 2.0ms preprocess, 105.1ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_365/extracted_frames/12309_wagon_365_1.jpg: 288x640 1 bus, 1 train, 110.2ms
# Speed: 3.7ms preprocess, 110.2ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_366/extracted_frames/12309_wagon_366_1.jpg: 288x640 1 train, 1 truck, 100.9ms
# Speed: 2.1ms preprocess, 100.9ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_367/extracted_frames/12309_wagon_367_1.jpg: 288x640 2 trains, 101.5ms
# Speed: 2.0ms preprocess, 101.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_368/extracted_frames/12309_wagon_368_1.jpg: 288x640 2 trains, 101.9ms
# Speed: 2.0ms preprocess, 101.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_369/extracted_frames/12309_wagon_369_1.jpg: 288x640 1 train, 102.2ms
# Speed: 2.1ms preprocess, 102.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_370/extracted_frames/12309_wagon_370_1.jpg: 288x640 1 train, 103.3ms
# Speed: 2.0ms preprocess, 103.3ms inference, 2.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_371/extracted_frames/12309_wagon_371_1.jpg: 288x640 2 trains, 101.8ms
# Speed: 2.1ms preprocess, 101.8ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_372/extracted_frames/12309_wagon_372_1.jpg: 288x640 1 train, 101.9ms
# Speed: 2.1ms preprocess, 101.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_373/extracted_frames/12309_wagon_373_1.jpg: 288x640 1 train, 104.2ms
# Speed: 2.0ms preprocess, 104.2ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_374/extracted_frames/12309_wagon_374_1.jpg: 288x640 1 train, 101.6ms
# Speed: 2.1ms preprocess, 101.6ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_375/extracted_frames/12309_wagon_375_1.jpg: 288x640 1 train, 104.7ms
# Speed: 2.3ms preprocess, 104.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_376/extracted_frames/12309_wagon_376_1.jpg: 288x640 1 bus, 1 train, 116.6ms
# Speed: 2.1ms preprocess, 116.6ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_377/extracted_frames/12309_wagon_377_1.jpg: 288x640 (no detections), 101.6ms
# Speed: 2.1ms preprocess, 101.6ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_378/extracted_frames/12309_wagon_378_1.jpg: 288x640 (no detections), 103.3ms
# Speed: 2.1ms preprocess, 103.3ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_379/extracted_frames/12309_wagon_379_1.jpg: 288x640 (no detections), 104.6ms
# Speed: 2.1ms preprocess, 104.6ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_380/extracted_frames/12309_wagon_380_1.jpg: 288x640 1 train, 109.3ms
# Speed: 2.0ms preprocess, 109.3ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_380/extracted_frames/12309_wagon_380_2.jpg: 288x640 (no detections), 102.5ms
# Speed: 2.0ms preprocess, 102.5ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_380/extracted_frames/12309_wagon_380_3.jpg: 288x640 1 train, 104.9ms
# Speed: 2.0ms preprocess, 104.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_380/extracted_frames/12309_wagon_380_4.jpg: 288x640 1 train, 103.6ms
# Speed: 2.1ms preprocess, 103.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/Processed_Video/individual_coaches/12309_wagon_380/extracted_frames/12309_wagon_380_5.jpg: 288x640 1 train, 123.1ms
# Speed: 2.1ms preprocess, 123.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)

# %%
import os
import shutil
from reportlab.lib.pagesizes import A4
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer, Image, PageBreak
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle
from reportlab.lib.units import inch
import logging

# Configure logging for better feedback
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

logger.info("\n--- Generating PDF report... ---")

def generate_pdf_report(report_data, output_filepath):
    doc = SimpleDocTemplate(output_filepath, pagesize=A4)
    styles = getSampleStyleSheet()

    # Custom style for summary text
    summary_style = ParagraphStyle(
        name='SummaryStyle',
        parent=styles['Normal'],
        fontSize=12,
        leading=16,
        spaceAfter=12
    )

    # FIX: Define a custom 'Small' style to replace the one that doesn't exist
    small_style = ParagraphStyle(
        name='SmallStyle',
        parent=styles['Normal'],
        fontSize=8,
        leading=10,
        spaceAfter=6
    )

    flowables = []

    # --- First Page: Summary Report ---
    flowables.append(Paragraph("<b>Train Side View Analysis Report</b>", styles['h1']))
    flowables.append(Spacer(1, 0.2 * inch))

    # General Summary
    total_wagons = sum(1 for item in report_data if item.get("wagon_type") == "wagon")
    total_engines = sum(1 for item in report_data if item.get("wagon_type") == "engine")

    flowables.append(Paragraph(f"<b>Summary Overview:</b>", styles['h2']))
    flowables.append(Paragraph(f"Train Number: <b>{TRAIN_NUMBER}</b>", summary_style))
    flowables.append(Paragraph(f"Total Engines Detected: <b>{total_engines}</b>", summary_style))
    flowables.append(Paragraph(f"Total Wagons (Coaches) Detected: <b>{total_wagons}</b>", summary_style))
    flowables.append(Spacer(1, 0.2 * inch))

    # CCTV Specific Information (placeholder counts)
    total_doors_open_overall = sum(item.get("total_doors_open_in_wagon", 0) for item in report_data if item["type"] == "wagon_data")
    total_doors_closed_overall = sum(item.get("total_doors_closed_in_wagon", 0) for item in report_data if item["type"] == "wagon_data")

    flowables.append(Paragraph(f"<b>CCTV Overview:</b>", styles['h2']))
    flowables.append(Paragraph(f"Door of wagon Open in this rack: <b>{'Yes' if total_doors_open_overall > 0 else 'No'}</b>", summary_style))
    flowables.append(Paragraph(f"Count of Door of wagon Open: <b>{total_doors_open_overall}</b>", summary_style))

    wagon_index_from_engine = []
    current_wagon_from_engine_idx = 0
    for item in report_data:
        if item.get("type") == "wagon_data":
            if item.get("wagon_type") == "engine":
                current_wagon_from_engine_idx = 0
            else:
                current_wagon_from_engine_idx += 1
                wagon_index_from_engine.append(str(current_wagon_from_engine_idx))
    flowables.append(Paragraph(f"Count Wagon from Engine: <b>{', '.join(wagon_index_from_engine)}</b>", summary_style))

    flowables.append(PageBreak())

    # --- Details for Each Wagon/Engine ---
    wagon_report_counter = 0
    for item in report_data:
        if item.get("type") == "wagon_data":
            wagon_report_counter += 1
            wagon_name = item.get("wagon_name", "N/A")
            wagon_type = item.get("wagon_type", "N/A")

            flowables.append(Paragraph(f"<b>{wagon_name.replace('_', ' ').title()} Details:</b>", styles['h2']))
            flowables.append(Paragraph(f"Type: {wagon_type.title()}", styles['Normal']))
            flowables.append(Paragraph(f"Individual Video: {item.get('video_path', 'N/A')}", styles['Normal']))

            if wagon_type == "wagon":
                flowables.append(Paragraph(f"Door Open Status: <b>{item.get('door_open_status_flag', 'N/A')}</b>", styles['Normal']))
                flowables.append(Paragraph(f"Doors Detected (Open): {item.get('total_doors_open_in_wagon', 0)}", styles['Normal']))
                flowables.append(Paragraph(f"Doors Detected (Closed): {item.get('total_doors_closed_in_wagon', 0)}", styles['Normal']))

            flowables.append(Spacer(1, 0.1 * inch))

            flowables.append(Paragraph("<b>Full Coverage Images:</b>", styles['h3']))
            images_for_this_wagon = item.get("full_coverage_images", [])
            if images_for_this_wagon:
                for img_path in images_for_this_wagon:
                    annotated_path = item["detected_components_by_image"].get(img_path, {}).get("annotated_image_path", None)
                    if annotated_path and os.path.exists(annotated_path):
                        img = Image(annotated_path, width=4*inch, height=3*inch)
                        flowables.append(img)
                        flowables.append(Paragraph(f"Image: {os.path.basename(annotated_path)}", small_style))
                        detections_for_image = item["detected_components_by_image"][img_path].get("detections", [])
                        if detections_for_image:
                            for det in detections_for_image:
                                flowables.append(Paragraph(f"- Detected: {det['class_name']} ({det['state']}) Conf: {det['confidence']:.2f}", small_style))
                        flowables.append(Spacer(1, 0.1 * inch))
                    else:
                        flowables.append(Paragraph(f"Could not load image: {os.path.basename(img_path)} or its annotation.", small_style))
            else:
                flowables.append(Paragraph("No full coverage images extracted for this wagon.", styles['Normal']))

            if wagon_report_counter < (total_wagons + total_engines):
                flowables.append(PageBreak())

    try:
        doc.build(flowables)
        logger.info(f"PDF report generated successfully: {output_filepath}")
    except Exception as e:
        logger.error(f"Error generating PDF: {e}")

pdf_report_path = os.path.join(report_output_dir, f"{TRAIN_NUMBER}_Train_Analysis_Report.pdf")
generate_pdf_report(report_data, pdf_report_path)

# --- Final Archiving ---
try:
    shutil.make_archive(OUTPUT_BASE_DIR, 'zip', OUTPUT_BASE_DIR)
    logger.info(f"Output compressed into '{OUTPUT_BASE_DIR}.zip'.")
except Exception as e:
    logger.error(f"Error zipping output folder: {e}")

logger.info("\n--- Processing complete! ---")
logger.info(f"You can now download '{OUTPUT_BASE_DIR}.zip' from the Colab file explorer (left sidebar).")
logger.info("\n--- Important Next Steps for Submission ---")
logger.info("1. Download the 'Processed_Video.zip' file from Colab.")
logger.info("2. Upload the unzipped contents to your Google Drive as specified.")
logger.info("3. Create your screen recording explaining the project.")
logger.info("4. Write your README.md file (setup, features, limitations).")
